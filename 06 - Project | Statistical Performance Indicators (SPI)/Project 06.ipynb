# %% [markdown]
# # 06 - Project // Statistical Performance Indicators (SPI)

# %% [markdown]
# https://github.com/LearnPythonWithRune/DataScienceWithPython/blob/main/jupyter/final/06%20-%20Project%20-%20Statistical%20Performance%20Indicators%20(SPI).ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
spi = pd.read_csv('https://github.com/ad3rinto/data-science-rune/raw/refs/heads/main/files/SPI/API_IQ.SPI.OVRL_DS2_en_csv_v2_3186678.csv', skiprows=4)
meta = pd.read_csv('https://github.com/ad3rinto/data-science-rune/raw/refs/heads/main/files/SPI/Metadata_Country_API_IQ.SPI.OVRL_DS2_en_csv_v2_3186678.csv')
gdp = pd.read_csv('https://github.com/ad3rinto/data-science-rune/raw/refs/heads/main/files/SPI/API_NY.GDP.PCAP.CD_DS2_en_csv_v2_3159040.csv', skiprows=4)

# %%
spi.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name Indicator Code  1960  \
# 0  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 1  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 2  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 3  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
# 4  Statistical performance indicators (SPI): Over...    IQ.SPI.OVRL   NaN
#
#    1961  1962  1963  1964  1965  ...  2012  2013  2014  2015       2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN        NaN
# ...

# %%
meta.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  Fiscal year end: March 20; reporting period fo...
# 3  22 countries, stretching from the westernmost ...
# 4                                                NaN
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
gdp.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  147.836769  147.238537  156.426780  182.521139  162.594548
# 2  NY.GDP.PCAP.CD   59.773234   59.860900   58.458009   78.706429   82.095307
# 3  NY.GDP.PCAP.CD  107.963779  113.114697  118.865837  123.478967  131.892939
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
# ...

# %% [markdown]
# SPI
#
# ---

# %%
spi = spi[['Country Code', '2019']]
spi.head()
# Out:
#   Country Code       2019
# 0          ABW        NaN
# 1          AFE        NaN
# 2          AFG  49.756250
# 3          AFW        NaN
# 4          AGO  54.945833

# %%
len(spi)
# Out:
# 266

# %%
spi.isna().sum()
# Out:
# Country Code     0
# 2019            92
# dtype: int64

# %%
spi = spi.dropna()
spi.head()
# Out:
#   Country Code       2019
# 2          AFG  49.756250
# 4          AGO  54.945833
# 5          ALB  75.382917
# 8          ARE  59.669167
# 9          ARG  64.595833

# %%
len(spi.dropna())
# Out:
# 174

# %%
spi = spi.rename(columns={'2019': 'SPI'})
spi.head()
# Out:
#   Country Code        SPI
# 2          AFG  49.756250
# 4          AGO  54.945833
# 5          ALB  75.382917
# 8          ARE  59.669167
# 9          ARG  64.595833

# %% [markdown]
# GDP
#
# ---

# %%
gdp = gdp[['Country Code', '2019']]
gdp.head()
# Out:
#   Country Code         2019
# 0          ABW          NaN
# 1          AFE  1485.307425
# 2          AFG   507.103392
# 3          AFW  1772.339155
# 4          AGO  2809.626088

# %%
len(gdp)
# Out:
# 266

# %%
gdp.isna().sum()
# Out:
# Country Code     0
# 2019            19
# dtype: int64

# %%
gdp = gdp.dropna()
gdp.head()
# Out:
#   Country Code         2019
# 1          AFE  1485.307425
# 2          AFG   507.103392
# 3          AFW  1772.339155
# 4          AGO  2809.626088
# 5          ALB  5355.847795

# %%
len(gdp)
# Out:
# 247

# %%
gdp = gdp.rename(columns={'2019': 'GDP per capita'})
gdp.head()
# Out:
#   Country Code  GDP per capita
# 1          AFE     1485.307425
# 2          AFG      507.103392
# 3          AFW     1772.339155
# 4          AGO     2809.626088
# 5          ALB     5355.847795

# %% [markdown]
# Meta
#
# ---
#
#
#
# ---

# %%
meta = meta[['Country Code', 'Region']]
meta.head()
# Out:
#   Country Code                     Region
# 0          ABW  Latin America & Caribbean
# 1          AFE                        NaN
# 2          AFG                 South Asia
# 3          AFW                        NaN
# 4          AGO         Sub-Saharan Africa

# %%
len(meta)
# Out:
# 265

# %% [markdown]
# **Merge**
#
# ---

# %%
#dataset = spi.merge(gdp, how='inner', on='Country Code')
#dataset = dataset.merge(meta, how='inner', on='Country Code')

# %%
dataset = spi.merge(gdp, how='inner', on='Country Code')
dataset.head()
# Out:
#   Country Code        SPI  GDP per capita
# 0          AFG  49.756250      507.103392
# 1          AGO  54.945833     2809.626088
# 2          ALB  75.382917     5355.847795
# 3          ARE  59.669167    43103.336293
# 4          ARG  64.595833     9912.281809

# %%
len(dataset)
# Out:
# 170

# %%
dataset = dataset.merge(meta, how='inner', on='Country Code')
dataset.head()
# Out:
#   Country Code        SPI  GDP per capita                      Region
# 0          AFG  49.756250      507.103392                  South Asia
# 1          AGO  54.945833     2809.626088          Sub-Saharan Africa
# 2          ALB  75.382917     5355.847795       Europe & Central Asia
# 3          ARE  59.669167    43103.336293  Middle East & North Africa
# 4          ARG  64.595833     9912.281809   Latin America & Caribbean

# %%
len(dataset)
# Out:
# 170

# %%
dataset.groupby('Region').mean()
# Out:
#                                   SPI  GDP per capita
# Region
# East Asia & Pacific         60.433021    13146.487797
# Europe & Central Asia       79.407031    27152.961460
# Latin America & Caribbean   61.290865     9074.663859
# Middle East & North Africa  58.008640    16966.440762
# North America               88.194792    55803.100832
# South Asia                  58.738281     3092.170830
# Sub-Saharan Africa          51.775572     2356.133699

# %%
dataset.groupby('Region').mean()['SPI'].plot.bar()

# %%
dataset.plot.scatter(x='GDP per capita', y='SPI')

# %%
dataset.plot.scatter(x='GDP per capita', y='SPI', logx=True)

# %% [markdown]
# **Plot**
#
# ---

# %%
dataset.groupby('Region').mean()['SPI'].sort_values(ascending=True).plot.barh(title='SPI by Region', ylabel='SPI')

# %%
colors = dataset['Region'].factorize()[0]

dataset.plot.scatter(x='GDP per capita', y='SPI', c=colors, logx=True, cmap='tab10')
