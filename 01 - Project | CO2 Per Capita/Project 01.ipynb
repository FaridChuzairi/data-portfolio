# %% [markdown]
# # 01 - Project // CO2 Per Capita

# %% [markdown]
# https://github.com/LearnPythonWithRune/DataScienceWithPython/blob/main/jupyter/final/01%20-%20Project%20-%20CO2%20Per%20Capita.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('https://github.com/ad3rinto/data-science-rune/raw/refs/heads/main/files/WorldBank-ATM.CO2E.PC_DS2.csv', index_col=0)

# %%
data.head()
# Out:
#              ABW       AFE       AFG       AFW       AGO       ALB  AND  \
# Year
# 1960  204.631696  0.906060  0.046057  0.090880  0.100835  1.258195  NaN
# 1961  208.837879  0.922474  0.053589  0.095283  0.082204  1.374186  NaN
# 1962  226.081890  0.930816  0.073721  0.096612  0.210533  1.439956  NaN
# 1963  214.785217  0.940570  0.074161  0.112376  0.202739  1.181681  NaN
# 1964  207.626699  0.996033  0.086174  0.133258  0.213562  1.111742  NaN
#
#            ARB       ARE       ARG  ...  VIR       VNM       VUT       WLD  \
# Year                                ...
# 1960  0.609268  0.119037  2.383343  ...  NaN  0.181947       NaN  3.121158
# 1961  0.662618  0.109136  2.458551  ...  NaN  0.183099       NaN  3.068090
# 1962  0.727117  0.163542  2.538447  ...  NaN  0.217694  0.595002  3.114839
# 1963  0.853116  0.175833  2.330685  ...  NaN  0.196997  0.471849  3.221195
# 1964  0.972381  0.132815  2.553442  ...  NaN  0.209870  0.864427  3.324046
#
# ...

# %%
data.shape
# Out:
# (59, 266)

# %%
data.dtypes
# Out:
# ABW    float64
# AFE    float64
# AFG    float64
# AFW    float64
# AGO    float64
#         ...
# XKX    float64
# YEM    float64
# ZAF    float64
# ZMB    float64
# ZWE    float64
# Length: 266, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1960 to 2018
# Columns: 266 entries, ABW to ZWE
# dtypes: float64(266)
# memory usage: 123.1 KB

# %%
data.isnull().any()
# Out:
# ABW     True
# AFE    False
# AFG    False
# AFW    False
# AGO    False
#        ...
# XKX     True
# YEM    False
# ZAF    False
# ZMB     True
# ZWE     True
# Length: 266, dtype: bool

# %%
data.isnull().sum().plot.hist(figsize=(20,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_clean = data.dropna(axis='columns')

# %%
len(data.columns), len(data_clean.columns)
# Out:
# (266, 191)

# %%
data_plot = (data_clean.loc[2018]-data_clean.loc[1998])/data_clean.loc[1998]

# %%
data_plot.describe()
# Out:
# count    191.000000
# mean       0.494745
# std        1.341795
# min       -0.737721
# 25%       -0.101786
# 50%        0.198752
# 75%        0.643839
# max       15.694284
# dtype: float64

# %%
data_plot.plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
(data_plot < 0).value_counts()
# Out:
# False    123
# True      68
# Name: count, dtype: int64

# %%
(data_plot < 0).value_counts().plot.pie(title='Countries with decrease CO2', colors=['r', 'g'], labels=['>=0', '< 0'], ylabel='1998-2018', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Countries with decrease CO2'}, ylabel='1998-2018'>

# %%
data_plot2 = (data_clean.loc[2018]-data_clean.loc[2008])/data_clean.loc[2008]

# %%
data_plot2.describe()
# Out:
# count    191.000000
# mean       0.162439
# std        0.650465
# min       -0.763271
# 25%       -0.126483
# 50%        0.051900
# 75%        0.268076
# max        6.848551
# dtype: float64

# %%
data_plot2.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
(data_plot2 < 0).value_counts()
# Out:
# False    107
# True      84
# Name: count, dtype: int64

# %%
(data_plot2 < 0).value_counts().plot.pie(title='Countries with decrease CO2 (2008-2018)', colors=['r', 'g'], labels=['>=0', '< 0'], ylabel='2008-2018', autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Countries with decrease CO2 (2008-2018)'}, ylabel='2008-2018'>
